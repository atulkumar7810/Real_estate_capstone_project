# %%
import numpy as np
import pandas as pd

# %%
# View all rows and columns
pd.set_option('display.max_rows', 10)
pd.set_option('display.max_columns', None)

# %%
# Import the data
df = pd.read_csv('../../Data_Scraping/Data/Gurgaon/Independent_House/ind_house.csv') # Independent Houses data

# %%
df.sample(5)
# Out:
#                                       property_name  \
# 126     4 Bedroom House for sale in Nirvana Country
# 413       12 Bedroom House for sale in Laxmi Garden
# 110  5 Bedroom House for sale in Sector 111 Gurgaon
# 251       5 Bedroom House for sale in Vishnu Garden
# 158     4 Bedroom House for sale in Nirvana Country
#
#                                                   link  \
# 126  https://www.99acres.com/4-bhk-bedroom-independ...
# 413  https://www.99acres.com/12-bhk-bedroom-indepen...
# 110  https://www.99acres.com/5-bhk-bedroom-independ...
# 251  https://www.99acres.com/5-bhk-bedroom-independ...
# 158  https://www.99acres.com/4-bhk-bedroom-independ...
#
#                          society       price             rate  \
# 126                          NaN     7 Crore  ₹ 23,333/sq.ft.
# 413       Laxmi Garden Sector-11   1.5 Crore  ₹ 12,820/sq.ft.
# 110  Puri Diplomatic Greens4.0 ★         NaN  ₹ 12,828/sq.ft.
# 251                          NaN  1.35 Crore   ₹ 3,857/sq.ft.
# 158       Unitech Deerwood Chase    15 Crore  ₹ 33,333/sq.ft.
#
#                           area  \
# 126      (223 sq.m.) Plot Area
# 413      (109 sq.m.) Plot Area
# 110  (650 sq.m.) Built-up Area
# 251  (325 sq.m.) Built-up Area
# 158      (418 sq.m.) Plot Area
#
#                                           areaWithType      bedRoom  \
# 126  Plot area 2400(222.97 sq.m.)Built Up area: 340...   4 Bedrooms
# 413                         Plot area 130(108.7 sq.m.)  12 Bedrooms
# 110                                                NaN          NaN
# 251  Built Up area: 3500 (325.16 sq.m.)Carpet area:...   5 Bedrooms
# 158                        Plot area 500(418.06 sq.m.)   4 Bedrooms
#
#         bathroom      balcony                             additionalRoom  \
# 126  4 Bathrooms  2 Balconies                               Servant Room
# 413  9 Bathrooms    1 Balcony  Pooja Room,Study Room,Servant Room,Others
# 110          NaN          NaN                                        NaN
# 251  3 Bathrooms  3 Balconies                                        NaN
# 158  4 Bathrooms  2 Balconies                               Servant Room
#
#                                                address noOfFloor      facing  \
# 126                  Nirvana Country, Gurgaon, Haryana  3 Floors  North-East
# 413    House No 477/23, Laxmi Garden, Gurgaon, Haryana  3 Floors        East
# 110               Sector 111 Gurgaon, Gurgaon, Haryana       NaN         NaN
# 251  Vishnu Garden, Sector 105, Vishnu Garden, Gurg...  3 Floors        East
# 158           Jf 67, Nirvana Country, Gurgaon, Haryana  2 Floors        West
#
#         agePossession                                    nearbyLocations  \
# 126      10+ Year Old  ['Radhakrishna Shani Mandir', 'Standard charte...
# 413   1 to 5 Year Old  ['Hanuman Mandir', 'Sharma Hospital Gurgaon', ...
# 110               NaN  ['Dwarka Sector 21 Metro Station', 'Gurgaon Dr...
# 251         undefined  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
# 158  5 to 10 Year Old  ['Sector 55-56 Metro Station', 'Raheja Mall', ...
#
#                                            description  \
# 126  4 bhk villa sale in nirvana country \nGated \n...
# 413  Property for sale. Area=130 sq yard; Front=30 ...
# 110  Puri diplomatic greens in sector-111 gurgaon, ...
# 251  Solar power for 3kwh, 3 independent flora are ...
# 158  A magnificent lifestyle curated for just the e...
#
#                                         furnishDetails  \
# 126  ['5 Wardrobe', '1 Dining Table', '5 Light', '5...
# 413  ['7 Wardrobe', '9 Fan', '1 Exhaust Fan', '2 Ge...
# 110                                                NaN
# 251  ['1 Wardrobe', '1 Fan', '1 Light', 'No AC', 'N...
# 158  ['6 Fan', '7 Light', 'No AC', 'No Bed', 'No Ch...
#
#                                               features  \
# 126  ['Security / Fire Alarm', 'Feng Shui / Vaastu ...
# 413  ['Security / Fire Alarm', 'High Ceiling Height...
# 110                                                NaN
# 251                                                NaN
# 158  ['Centrally Air Conditioned', 'Water purifier'...
#
#                                                 rating property_id
# 126  ['Environment5 out of 5', 'Lifestyle5 out of 5...   A68809650
# 413  ['Environment4 out of 5', 'Lifestyle4 out of 5...   S57354016
# 110                                                NaN   V69909776
# 251  ['Environment3 out of 5', 'Lifestyle4 out of 5...   Y69750790
# 158  ['Environment5 out of 5', 'Lifestyle5 out of 5...   M69448868

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1037 entries, 0 to 1036
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    1037 non-null   object
#  1   link             1037 non-null   object
#  2   society          453 non-null    object
#  3   price            968 non-null    object
#  4   rate             999 non-null    object
#  5   area             1037 non-null   object
#  6   areaWithType     987 non-null    object
#  7   bedRoom          987 non-null    object
#  8   bathroom         987 non-null    object
#  9   balcony          987 non-null    object
#  10  additionalRoom   589 non-null    object
#  11  address          1031 non-null   object
#  12  noOfFloor        967 non-null    object
#  13  facing           674 non-null    object
#  14  agePossession    987 non-null    object
#  15  nearbyLocations  913 non-null    object
#  16  description      1036 non-null   object
#  17  furnishDetails   743 non-null    object
#  18  features         674 non-null    object
#  19  rating           907 non-null    object
#  20  property_id      1036 non-null   object
# dtypes: object(21)
# memory usage: 170.3+ KB

# %%
# Check for duplicates
df.duplicated().sum()
# Out:
# 13

# %%
df.drop_duplicates(inplace=True)

# %%
# Check for missing values
df.isnull().sum()
# Out:
# property_name       0
# link                0
# society           579
# price              69
# rate               38
#                  ...
# description         1
# furnishDetails    292
# features          362
# rating            130
# property_id         1
# Length: 21, dtype: int64

# %%
# Columns to drop: Link, 
df.drop(columns=['link', 'property_id'], inplace=True)

# %%
df.head()
# Out:
#                                       property_name           society  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  Bptp Visionnaire
# 1  5 Bedroom House for sale in Sector 21A Faridabad               NaN
# 2  10 Bedroom House for sale in Sushant Lok Phase 1               NaN
# 3    21 Bedroom House for sale in Sector 54 Gurgaon               NaN
# 4  12 Bedroom House for sale in Sushant Lok Phase 1               NaN
#
#         price              rate                   area  \
# 0  5.25 Crore   ₹ 20,115/sq.ft.  (242 sq.m.) Plot Area
# 1   5.7 Crore  ₹ 105,751/sq.ft.   (50 sq.m.) Plot Area
# 2   2.1 Crore   ₹ 38,251/sq.ft.   (51 sq.m.) Plot Area
# 3     5 Crore   ₹ 43,066/sq.ft.  (108 sq.m.) Plot Area
# 4     3 Crore   ₹ 53,763/sq.ft.   (52 sq.m.) Plot Area
#
#                   areaWithType      bedRoom      bathroom       balcony  \
# 0  Plot area 290(242.48 sq.m.)   5 Bedrooms   4 Bathrooms  3+ Balconies
# 1   Plot area 539(50.07 sq.m.)   5 Bedrooms   4 Bathrooms   2 Balconies
# 2       Plot area 61(51 sq.m.)  10 Bedrooms  10 Bathrooms  3+ Balconies
# 3  Plot area 129(107.86 sq.m.)  21 Bedrooms  21 Bathrooms  3+ Balconies
# 4    Plot area 62(51.84 sq.m.)  12 Bedrooms  12 Bathrooms  3+ Balconies
#
#                        additionalRoom  \
# 0                        Servant Room
# 1  Store Room,Pooja Room,Servant Room
# 2                        Servant Room
# 3                        Servant Room
# 4                              Others
#
#                                        address noOfFloor      facing  \
# 0    29b, Sector 70A Gurgaon, Gurgaon, Haryana  3 Floors  North-East
# 1       Sector 21A Faridabad, Gurgaon, Haryana  2 Floors         NaN
# 2        Sushant Lok Phase 1, Gurgaon, Haryana  5 Floors        West
# 3          Sector 54 Gurgaon, Gurgaon, Haryana  5 Floors       North
# 4  1228, Sushant Lok Phase 1, Gurgaon, Haryana  5 Floors        West
#
#       agePossession                                    nearbyLocations  \
# 0   0 to 1 Year Old  ['Good Earth City Center 2', 'Kunskapsskolan I...
# 1  5 to 10 Year Old                                                NaN
# 2   0 to 1 Year Old  ['Sector 42-43 metro station', 'Huda city cent...
# 3   1 to 5 Year Old  ['Sector 53-54 metro station', 'Sector 54 chow...
# 4   Within 6 months  ['Sector 42-43 metro station', 'Huda city cent...
#
#                                          description  \
# 0  Do you wish to buy an independent house in sec...
# 1  Hi, we have an independent house/villa availab...
# 2  Monthly rental income is rs1,40,000/- Best opt...
# 3  129 sq yd plot size. 5 floors built up , fully...
# 4  Best for investment purpose. Fully furnished b...
#
#                                       furnishDetails  \
# 0  ['1 Wardrobe', '1 Fan', '1 Exhaust Fan', '1 Ge...
# 1  ['1 Water Purifier', '5 Fan', '1 Exhaust Fan',...
# 2  ['10 Bed', '3 Fan', '10 Geyser', '2 Light', 'N...
# 3  ['1 Water Purifier', '21 Fan', '1 Fridge', '1 ...
# 4  ['1 Water Purifier', '1 Fridge', '12 Fan', '1 ...
#
#                                             features  \
# 0  ['Feng Shui / Vaastu Compliant', 'Private Gard...
# 1  ['Private Garden / Terrace', 'Park', 'Visitor ...
# 2  ['Maintenance Staff', 'Water Storage', 'Visito...
# 3  ['Feng Shui / Vaastu Compliant', 'Private Gard...
# 4  ['Maintenance Staff', 'Water Storage', 'Visito...
#
#                                               rating
# 0  ['Environment5 out of 5', 'Lifestyle4 out of 5...
# 1                                                NaN
# 2  ['Environment5 out of 5', 'Lifestyle5 out of 5...
# 3  ['Environment4 out of 5', 'Lifestyle5 out of 5...
# 4  ['Environment5 out of 5', 'Lifestyle5 out of 5...

# %%
# Renaming the columns
df.rename(columns={'rate': 'price_per_sqft'}, inplace=True)
df.head()
# Out:
#                                       property_name           society  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  Bptp Visionnaire
# 1  5 Bedroom House for sale in Sector 21A Faridabad               NaN
# 2  10 Bedroom House for sale in Sushant Lok Phase 1               NaN
# 3    21 Bedroom House for sale in Sector 54 Gurgaon               NaN
# 4  12 Bedroom House for sale in Sushant Lok Phase 1               NaN
#
#         price    price_per_sqft                   area  \
# 0  5.25 Crore   ₹ 20,115/sq.ft.  (242 sq.m.) Plot Area
# 1   5.7 Crore  ₹ 105,751/sq.ft.   (50 sq.m.) Plot Area
# 2   2.1 Crore   ₹ 38,251/sq.ft.   (51 sq.m.) Plot Area
# 3     5 Crore   ₹ 43,066/sq.ft.  (108 sq.m.) Plot Area
# 4     3 Crore   ₹ 53,763/sq.ft.   (52 sq.m.) Plot Area
#
#                   areaWithType      bedRoom      bathroom       balcony  \
# 0  Plot area 290(242.48 sq.m.)   5 Bedrooms   4 Bathrooms  3+ Balconies
# 1   Plot area 539(50.07 sq.m.)   5 Bedrooms   4 Bathrooms   2 Balconies
# 2       Plot area 61(51 sq.m.)  10 Bedrooms  10 Bathrooms  3+ Balconies
# 3  Plot area 129(107.86 sq.m.)  21 Bedrooms  21 Bathrooms  3+ Balconies
# 4    Plot area 62(51.84 sq.m.)  12 Bedrooms  12 Bathrooms  3+ Balconies
#
#                        additionalRoom  \
# 0                        Servant Room
# 1  Store Room,Pooja Room,Servant Room
# 2                        Servant Room
# 3                        Servant Room
# 4                              Others
#
#                                        address noOfFloor      facing  \
# 0    29b, Sector 70A Gurgaon, Gurgaon, Haryana  3 Floors  North-East
# 1       Sector 21A Faridabad, Gurgaon, Haryana  2 Floors         NaN
# 2        Sushant Lok Phase 1, Gurgaon, Haryana  5 Floors        West
# 3          Sector 54 Gurgaon, Gurgaon, Haryana  5 Floors       North
# 4  1228, Sushant Lok Phase 1, Gurgaon, Haryana  5 Floors        West
#
#       agePossession                                    nearbyLocations  \
# 0   0 to 1 Year Old  ['Good Earth City Center 2', 'Kunskapsskolan I...
# 1  5 to 10 Year Old                                                NaN
# 2   0 to 1 Year Old  ['Sector 42-43 metro station', 'Huda city cent...
# 3   1 to 5 Year Old  ['Sector 53-54 metro station', 'Sector 54 chow...
# 4   Within 6 months  ['Sector 42-43 metro station', 'Huda city cent...
#
#                                          description  \
# 0  Do you wish to buy an independent house in sec...
# 1  Hi, we have an independent house/villa availab...
# 2  Monthly rental income is rs1,40,000/- Best opt...
# 3  129 sq yd plot size. 5 floors built up , fully...
# 4  Best for investment purpose. Fully furnished b...
#
#                                       furnishDetails  \
# 0  ['1 Wardrobe', '1 Fan', '1 Exhaust Fan', '1 Ge...
# 1  ['1 Water Purifier', '5 Fan', '1 Exhaust Fan',...
# 2  ['10 Bed', '3 Fan', '10 Geyser', '2 Light', 'N...
# 3  ['1 Water Purifier', '21 Fan', '1 Fridge', '1 ...
# 4  ['1 Water Purifier', '1 Fridge', '12 Fan', '1 ...
#
#                                             features  \
# 0  ['Feng Shui / Vaastu Compliant', 'Private Gard...
# 1  ['Private Garden / Terrace', 'Park', 'Visitor ...
# 2  ['Maintenance Staff', 'Water Storage', 'Visito...
# 3  ['Feng Shui / Vaastu Compliant', 'Private Gard...
# 4  ['Maintenance Staff', 'Water Storage', 'Visito...
#
#                                               rating
# 0  ['Environment5 out of 5', 'Lifestyle4 out of 5...
# 1                                                NaN
# 2  ['Environment5 out of 5', 'Lifestyle5 out of 5...
# 3  ['Environment4 out of 5', 'Lifestyle5 out of 5...
# 4  ['Environment5 out of 5', 'Lifestyle5 out of 5...

# %% [markdown]
# # Univariate Analysis

# %%
# Society
df['society'].value_counts()
# Out:
# International City by SOBHA Phase 2    26
# Emaar MGF Marbella                     26
# Vipul Tatvam Villa                     24
# International City by Sobha Phase 1    23
# Unitech Uniworld Resorts               13
#                                        ..
# Jacobpura                               1
# Indiabulls Centrum Park3.7 ★            1
# Madan puri                              1
# Signature Global Park4.0 ★              1
# ROW HOUSE                               1
# Name: society, Length: 185, dtype: int64

# %%
df['society'].isnull().sum()
# Out:
# 579

# %%
import re
df['society'] = df['society'].apply(lambda name: re.sub(r'\d+(\.\d+)?\s?★', "", str(name)).strip()).str.lower()

# %%
df['society'] = df['society'].str.replace('nan', 'independent')

# %%
df['society'].value_counts().shape  # Checking number of unique socities
# Out:
# (183,)

# %%
df['society'].value_counts()
# Out:
# independent                            579
# emaar mgf marbella                      26
# international city by sobha phase 2     26
# vipul tatvam villa                      24
# international city by sobha phase 1     23
#                                       ...
# huda flats                               1
# jacobpura                                1
# indiabulls centrum park                  1
# madan puri                               1
# huda plot sector 38                      1
# Name: society, Length: 183, dtype: int64

# %%
# Price
df['price'].value_counts()
# Out:
# 3.5 Crore     19
# 5.5 Crore     17
# 6.5 Crore     16
# 6 Crore       14
# 5 Crore       13
#               ..
# 8.8 Crore      1
# 1.34 Crore     1
# 46 Lac         1
# 2.6 Crore      1
# 2.98 Crore     1
# Name: price, Length: 302, dtype: int64

# %%
df['price'].isnull().sum()
# Out:
# 69

# %%
df[df['price'] == 'Price on Request'].shape
# Out:
# (10, 19)

# %%
df = df[df['price'] != 'Price on Request']

# %%
# Create a function to convert all prices in same unit

def normalize_price(x):
    if type(x) == float:
        return x
    else:
        if x[1] == 'Lac':
            return round(float(x[0])/100, 2)
        else:
            return round(float(x[0]), 2)

# %%
df['price'] = df['price'].str.split(' ').apply(normalize_price)

# %%
df.head()
# Out:
#                                       property_name           society  price  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  bptp visionnaire   5.25
# 1  5 Bedroom House for sale in Sector 21A Faridabad       independent   5.70
# 2  10 Bedroom House for sale in Sushant Lok Phase 1       independent   2.10
# 3    21 Bedroom House for sale in Sector 54 Gurgaon       independent   5.00
# 4  12 Bedroom House for sale in Sushant Lok Phase 1       independent   3.00
#
#      price_per_sqft                   area                 areaWithType  \
# 0   ₹ 20,115/sq.ft.  (242 sq.m.) Plot Area  Plot area 290(242.48 sq.m.)
# 1  ₹ 105,751/sq.ft.   (50 sq.m.) Plot Area   Plot area 539(50.07 sq.m.)
# 2   ₹ 38,251/sq.ft.   (51 sq.m.) Plot Area       Plot area 61(51 sq.m.)
# 3   ₹ 43,066/sq.ft.  (108 sq.m.) Plot Area  Plot area 129(107.86 sq.m.)
# 4   ₹ 53,763/sq.ft.   (52 sq.m.) Plot Area    Plot area 62(51.84 sq.m.)
#
#        bedRoom      bathroom       balcony  \
# 0   5 Bedrooms   4 Bathrooms  3+ Balconies
# 1   5 Bedrooms   4 Bathrooms   2 Balconies
# 2  10 Bedrooms  10 Bathrooms  3+ Balconies
# 3  21 Bedrooms  21 Bathrooms  3+ Balconies
# 4  12 Bedrooms  12 Bathrooms  3+ Balconies
#
#                        additionalRoom  \
# 0                        Servant Room
# 1  Store Room,Pooja Room,Servant Room
# 2                        Servant Room
# 3                        Servant Room
# 4                              Others
#
#                                        address noOfFloor      facing  \
# 0    29b, Sector 70A Gurgaon, Gurgaon, Haryana  3 Floors  North-East
# 1       Sector 21A Faridabad, Gurgaon, Haryana  2 Floors         NaN
# 2        Sushant Lok Phase 1, Gurgaon, Haryana  5 Floors        West
# 3          Sector 54 Gurgaon, Gurgaon, Haryana  5 Floors       North
# 4  1228, Sushant Lok Phase 1, Gurgaon, Haryana  5 Floors        West
#
#       agePossession                                    nearbyLocations  \
# 0   0 to 1 Year Old  ['Good Earth City Center 2', 'Kunskapsskolan I...
# 1  5 to 10 Year Old                                                NaN
# 2   0 to 1 Year Old  ['Sector 42-43 metro station', 'Huda city cent...
# 3   1 to 5 Year Old  ['Sector 53-54 metro station', 'Sector 54 chow...
# 4   Within 6 months  ['Sector 42-43 metro station', 'Huda city cent...
#
#                                          description  \
# 0  Do you wish to buy an independent house in sec...
# 1  Hi, we have an independent house/villa availab...
# 2  Monthly rental income is rs1,40,000/- Best opt...
# 3  129 sq yd plot size. 5 floors built up , fully...
# 4  Best for investment purpose. Fully furnished b...
#
#                                       furnishDetails  \
# 0  ['1 Wardrobe', '1 Fan', '1 Exhaust Fan', '1 Ge...
# 1  ['1 Water Purifier', '5 Fan', '1 Exhaust Fan',...
# 2  ['10 Bed', '3 Fan', '10 Geyser', '2 Light', 'N...
# 3  ['1 Water Purifier', '21 Fan', '1 Fridge', '1 ...
# 4  ['1 Water Purifier', '1 Fridge', '12 Fan', '1 ...
#
#                                             features  \
# 0  ['Feng Shui / Vaastu Compliant', 'Private Gard...
# 1  ['Private Garden / Terrace', 'Park', 'Visitor ...
# 2  ['Maintenance Staff', 'Water Storage', 'Visito...
# 3  ['Feng Shui / Vaastu Compliant', 'Private Gard...
# 4  ['Maintenance Staff', 'Water Storage', 'Visito...
#
#                                               rating
# 0  ['Environment5 out of 5', 'Lifestyle4 out of 5...
# 1                                                NaN
# 2  ['Environment5 out of 5', 'Lifestyle5 out of 5...
# 3  ['Environment4 out of 5', 'Lifestyle5 out of 5...
# 4  ['Environment5 out of 5', 'Lifestyle5 out of 5...

# %%
# price per sqft
df['price_per_sqft'].value_counts()
# Out:
# ₹ 22,222/sq.ft.    14
# ₹ 11,111/sq.ft.    11
# ₹ 33,333/sq.ft.    11
# ₹ 10,000/sq.ft.    10
# ₹ 26,667/sq.ft.     6
#                    ..
# ₹ 151/sq.ft.        1
# ₹ 25,103/sq.ft.     1
# ₹ 14,954/sq.ft.     1
# ₹ 8,784/sq.ft.      1
# ₹ 33,129/sq.ft.     1
# Name: price_per_sqft, Length: 751, dtype: int64

# %%
# get only price per sqft
df['price_per_sqft'] = df['price_per_sqft'].str.split('/').str.get(0).str.replace('₹', '').str.replace(',','').str.strip().astype('float')

# %%
df.sample(5)
# Out:
#                                        property_name  \
# 519              3 Bedroom House for sale in Bhondsi
# 243        7 Bedroom House for sale in Rajendra Park
# 1022   5 Bedroom House for sale in Sector 46 Gurgaon
# 62    5 Bedroom House for sale in Sector 109 Gurgaon
# 456          4 Bedroom House for sale in DLF Phase 3
#
#                                   society  price  price_per_sqft  \
# 519                           independent   0.44          4251.0
# 243                           independent   1.20         13333.0
# 1022                          independent   4.25         23148.0
# 62    international city by sobha phase 2    NaN         13622.0
# 456                dlf city plots phase 3   1.44         26667.0
#
#                                area                    areaWithType  \
# 519          (96 sq.m.) Carpet Area  Carpet area: 115 (96.15 sq.m.)
# 243            (84 sq.m.) Plot Area      Plot area 900(83.61 sq.m.)
# 1022          (171 sq.m.) Plot Area     Plot area 204(170.57 sq.m.)
# 62    (467-681 sq.m.) Built-up Area                             NaN
# 456            (50 sq.m.) Plot Area       Plot area 60(50.17 sq.m.)
#
#          bedRoom     bathroom      balcony     additionalRoom  \
# 519   3 Bedrooms  2 Bathrooms    1 Balcony  Pooja Room,Others
# 243   7 Bedrooms  4 Bathrooms    1 Balcony             Others
# 1022  5 Bedrooms  4 Bathrooms  2 Balconies         Store Room
# 62           NaN          NaN          NaN                NaN
# 456   4 Bedrooms  2 Bathrooms  2 Balconies                NaN
#
#                                      address noOfFloor      facing  \
# 519                Bhondsi, Gurgaon, Haryana  1 Floors         NaN
# 243          Rajendra Park, Gurgaon, Haryana  2 Floors  South-West
# 1022     Sector 46 Gurgaon, Gurgaon, Haryana  3 Floors  North-East
# 62      Sector 109 Gurgaon, Gurgaon, Haryana       NaN         NaN
# 456   S Block, DLF Phase 3, Gurgaon, Haryana  1 Floors         NaN
#
#          agePossession                                    nearbyLocations  \
# 519    1 to 5 Year Old                                                NaN
# 243   5 to 10 Year Old  ['Palam Vihar Vyapar kendra', 'Chintapurni Man...
# 1022  5 to 10 Year Old  ['Axis bank ATM', 'State bank of india ATM', '...
# 62                 NaN  ['Dwarka Sector 21 Metro Station', 'Pacific D2...
# 456       10+ Year Old  ['Dlf phase 3 metro station', 'Micromax moulsa...
#
#                                             description  \
# 519   This spacious 3 bhk independent house is avail...
# 243   12x12 and 13x12 rooms 2.5 floor buildup area t...
# 1022  204 square yard built up property available fo...
# 62    International city by sobha phase 2 in sector-...
# 456   60 yard plot , s block , all aminities near bu...
#
#                                          furnishDetails  \
# 519                                                 NaN
# 243   ['1 Geyser', '17 Light', '3 Wardrobe', 'No AC'...
# 1022  ['4 Wardrobe', '10 Fan', '1 Exhaust Fan', '50 ...
# 62                                                  NaN
# 456                                                  []
#
#                                                features  \
# 519   ['Water Storage', 'Recently Renovated', 'Visit...
# 243                ['Water Storage', 'Visitor Parking']
# 1022  ['Feng Shui / Vaastu Compliant', 'High Ceiling...
# 62                                                  NaN
# 456                                            ['Park']
#
#                                                  rating
# 519   ['Environment4 out of 5', 'Lifestyle4 out of 5...
# 243   ['Environment4 out of 5', 'Lifestyle4 out of 5...
# 1022  ['Environment4 out of 5', 'Safety4 out of 5', ...
# 62    ['Environment5 out of 5', 'Lifestyle4 out of 5...
# 456   ['Environment4 out of 5', 'Lifestyle5 out of 5...

# %%
# bedrooms
df['bedRoom'].value_counts()
# Out:
# 4 Bedrooms     232
# 5 Bedrooms     194
# 3 Bedrooms     146
# 2 Bedrooms      88
# 6 Bedrooms      81
#               ...
# 20 Bedrooms      1
# 21 Bedrooms      1
# 36 Bedrooms      1
# 34 Bedrooms      1
# 14 Bedrooms      1
# Name: bedRoom, Length: 21, dtype: int64

# %%
df = df[~df['bedRoom'].isnull()]

# %%
df.head()
# Out:
#                                       property_name           society  price  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  bptp visionnaire   5.25
# 1  5 Bedroom House for sale in Sector 21A Faridabad       independent   5.70
# 2  10 Bedroom House for sale in Sushant Lok Phase 1       independent   2.10
# 3    21 Bedroom House for sale in Sector 54 Gurgaon       independent   5.00
# 4  12 Bedroom House for sale in Sushant Lok Phase 1       independent   3.00
#
#    price_per_sqft                   area                 areaWithType  \
# 0         20115.0  (242 sq.m.) Plot Area  Plot area 290(242.48 sq.m.)
# 1        105751.0   (50 sq.m.) Plot Area   Plot area 539(50.07 sq.m.)
# 2         38251.0   (51 sq.m.) Plot Area       Plot area 61(51 sq.m.)
# 3         43066.0  (108 sq.m.) Plot Area  Plot area 129(107.86 sq.m.)
# 4         53763.0   (52 sq.m.) Plot Area    Plot area 62(51.84 sq.m.)
#
#        bedRoom      bathroom       balcony  \
# 0   5 Bedrooms   4 Bathrooms  3+ Balconies
# 1   5 Bedrooms   4 Bathrooms   2 Balconies
# 2  10 Bedrooms  10 Bathrooms  3+ Balconies
# 3  21 Bedrooms  21 Bathrooms  3+ Balconies
# 4  12 Bedrooms  12 Bathrooms  3+ Balconies
#
#                        additionalRoom  \
# 0                        Servant Room
# 1  Store Room,Pooja Room,Servant Room
# 2                        Servant Room
# 3                        Servant Room
# 4                              Others
#
#                                        address noOfFloor      facing  \
# 0    29b, Sector 70A Gurgaon, Gurgaon, Haryana  3 Floors  North-East
# 1       Sector 21A Faridabad, Gurgaon, Haryana  2 Floors         NaN
# 2        Sushant Lok Phase 1, Gurgaon, Haryana  5 Floors        West
# 3          Sector 54 Gurgaon, Gurgaon, Haryana  5 Floors       North
# 4  1228, Sushant Lok Phase 1, Gurgaon, Haryana  5 Floors        West
#
#       agePossession                                    nearbyLocations  \
# 0   0 to 1 Year Old  ['Good Earth City Center 2', 'Kunskapsskolan I...
# 1  5 to 10 Year Old                                                NaN
# 2   0 to 1 Year Old  ['Sector 42-43 metro station', 'Huda city cent...
# 3   1 to 5 Year Old  ['Sector 53-54 metro station', 'Sector 54 chow...
# 4   Within 6 months  ['Sector 42-43 metro station', 'Huda city cent...
#
#                                          description  \
# 0  Do you wish to buy an independent house in sec...
# 1  Hi, we have an independent house/villa availab...
# 2  Monthly rental income is rs1,40,000/- Best opt...
# 3  129 sq yd plot size. 5 floors built up , fully...
# 4  Best for investment purpose. Fully furnished b...
#
#                                       furnishDetails  \
# 0  ['1 Wardrobe', '1 Fan', '1 Exhaust Fan', '1 Ge...
# 1  ['1 Water Purifier', '5 Fan', '1 Exhaust Fan',...
# 2  ['10 Bed', '3 Fan', '10 Geyser', '2 Light', 'N...
# 3  ['1 Water Purifier', '21 Fan', '1 Fridge', '1 ...
# 4  ['1 Water Purifier', '1 Fridge', '12 Fan', '1 ...
#
#                                             features  \
# 0  ['Feng Shui / Vaastu Compliant', 'Private Gard...
# 1  ['Private Garden / Terrace', 'Park', 'Visitor ...
# 2  ['Maintenance Staff', 'Water Storage', 'Visito...
# 3  ['Feng Shui / Vaastu Compliant', 'Private Gard...
# 4  ['Maintenance Staff', 'Water Storage', 'Visito...
#
#                                               rating
# 0  ['Environment5 out of 5', 'Lifestyle4 out of 5...
# 1                                                NaN
# 2  ['Environment5 out of 5', 'Lifestyle5 out of 5...
# 3  ['Environment4 out of 5', 'Lifestyle5 out of 5...
# 4  ['Environment5 out of 5', 'Lifestyle5 out of 5...

# %%
df['bedRoom'] = df['bedRoom'].str.split(' ').str.get(0).astype('int')

# %%
df.sample(5)
# Out:
#                                       property_name             society  \
# 735         4 Bedroom House for sale in Palam Vihar         independent
# 888  2 Bedroom House for sale in Sector 70A Gurgaon       bptp pedestal
# 20     9 Bedroom House for sale in Sector 9 Gurgaon         independent
# 970   3 Bedroom House for sale in Sector 48 Gurgaon  vipul tatvam villa
# 177   4 Bedroom House for sale in Sector 56 Gurgaon         independent
#
#      price  price_per_sqft                     area  \
# 735   2.95         15989.0    (171 sq.m.) Plot Area
# 888   0.92          7750.0  (110 sq.m.) Carpet Area
# 20    3.40         12938.0    (244 sq.m.) Plot Area
# 970   5.50         21219.0    (241 sq.m.) Plot Area
# 177   4.00         26613.0    (140 sq.m.) Plot Area
#
#                          areaWithType  bedRoom     bathroom       balcony  \
# 735       Plot area 205(171.41 sq.m.)        4  4 Bathrooms  3+ Balconies
# 888  Carpet area: 1187 (110.28 sq.m.)        2  3 Bathrooms  3+ Balconies
# 20        Plot area 292(244.15 sq.m.)        9  9 Bathrooms   3 Balconies
# 970        Plot area 288(240.8 sq.m.)        3  6 Bathrooms   2 Balconies
# 177       Plot area 167(139.63 sq.m.)        4  4 Bathrooms  3+ Balconies
#
#           additionalRoom                                    address noOfFloor  \
# 735                  NaN              Palam Vihar, Gurgaon, Haryana  2 Floors
# 888               Others  123, Sector 70A Gurgaon, Gurgaon, Haryana  3 Floors
# 20                   NaN         Sector 9 Gurgaon, Gurgaon, Haryana  3 Floors
# 970  Servant Room,Others        Sector 48 Gurgaon, Gurgaon, Haryana  2 Floors
# 177                  NaN        Sector 56 Gurgaon, Gurgaon, Haryana  2 Floors
#
#          facing     agePossession  \
# 735  North-West      10+ Year Old
# 888  North-East   0 to 1 Year Old
# 20         West  5 to 10 Year Old
# 970       North  5 to 10 Year Old
# 177         NaN   1 to 5 Year Old
#
#                                        nearbyLocations  \
# 735  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
# 888  ['Ninex Mall', 'Airia Mall', 'Meditree Market'...
# 20   ['State bank ATM', 'Esic Hospital Gurugram', '...
# 970  ['Athena', 'Star Mall', 'The Sixth Element Sch...
# 177  ['Sector metro station', 'Sector metro station...
#
#                                            description  \
# 735  205 sq yard corner property available for sale...
# 888  Wishing to settle down in an individual house ...
# 20   292 square yards triple story made 9 bhk house...
# 970  Vipul tatvam luxury 3bhk duplex villa \nSemi f...
# 177  Two storey property adjacent to park , close p...
#
#                                         furnishDetails  \
# 735  ['4 Wardrobe', '4 Fan', '1 Exhaust Fan', '10 L...
# 888  ['3 AC', 'No Bed', 'No Chimney', 'No Curtains'...
# 20   ['9 Wardrobe', '12 Fan', '1 Exhaust Fan', '50 ...
# 970  ['3 Wardrobe', '5 Fan', '1 Exhaust Fan', '4 Ge...
# 177  ['3 Wardrobe', '8 Fan', '1 Exhaust Fan', '2 Ge...
#
#                                               features  \
# 735  ['Feng Shui / Vaastu Compliant', 'Maintenance ...
# 888  ['Security / Fire Alarm', 'Feng Shui / Vaastu ...
# 20   ['Feng Shui / Vaastu Compliant', 'Private Gard...
# 970  ['Security / Fire Alarm', 'Feng Shui / Vaastu ...
# 177  ['Private Garden / Terrace', 'Water Storage', ...
#
#                                                 rating
# 735  ['Environment5 out of 5', 'Lifestyle5 out of 5...
# 888  ['Environment5 out of 5', 'Safety4 out of 5', ...
# 20   ['Environment4 out of 5', 'Lifestyle4 out of 5...
# 970  ['Environment4 out of 5', 'Safety4 out of 5', ...
# 177  ['Environment4 out of 5', 'Lifestyle5 out of 5...

# %%
# bathroom
df['bathroom'].value_counts()
# Out:
# 4 Bathrooms     228
# 3 Bathrooms     165
# 5 Bathrooms     137
# 2 Bathrooms     114
# 6 Bathrooms      82
#                ...
# 17 Bathrooms      3
# 14 Bathrooms      2
# 21 Bathrooms      1
# 36 Bathrooms      1
# 34 Bathrooms      1
# Name: bathroom, Length: 21, dtype: int64

# %%
df[df['bathroom'].isnull()]
# Out:
# Empty DataFrame
# Columns: [property_name, society, price, price_per_sqft, area, areaWithType, bedRoom, bathroom, balcony, additionalRoom, address, noOfFloor, facing, agePossession, nearbyLocations, description, furnishDetails, features, rating]
# Index: []

# %%
df['bathroom'] = df['bathroom'].str.split(' ').str.get(0).astype('int')

# %%
df.sample(5)
# Out:
#                                         property_name  \
# 694  11 Bedroom House for sale in Sushant Lok Phase 1
# 150   6 Bedroom House for sale in Sushant Lok Phase 1
# 961       4 Bedroom House for sale in Uppals Southend
# 195           4 Bedroom House for sale in Maruti Kunj
# 13            5 Bedroom House for sale in DLF Phase 1
#
#                      society  price  price_per_sqft  \
# 694              independent   2.25          7500.0
# 150  ansal sushant lok plots   5.80         29974.0
# 961           uppal southend   6.75         32328.0
# 195              independent   0.70          4117.0
# 13               independent  15.00         33200.0
#
#                           area  \
# 694       (51 sq.m.) Plot Area
# 150      (180 sq.m.) Plot Area
# 961  (194 sq.m.) Built-up Area
# 195      (158 sq.m.) Plot Area
# 13       (420 sq.m.) Plot Area
#
#                                           areaWithType  bedRoom  bathroom  \
# 694  Plot area 550(51.1 sq.m.)Built Up area: 3000 s...       11        11
# 150                        Plot area 215(179.77 sq.m.)        6         6
# 961                  Built Up area: 232 (193.98 sq.m.)        4         4
# 195                       Plot area 1700(157.94 sq.m.)        4         4
# 13                         Plot area 502(419.74 sq.m.)        5         6
#
#           balcony                                 additionalRoom  \
# 694  3+ Balconies                                         Others
# 150   3 Balconies                            Servant Room,Others
# 961   3 Balconies                                   Servant Room
# 195     1 Balcony                                            NaN
# 13   3+ Balconies  Pooja Room,Study Room,Servant Room,Store Room
#
#                                     address noOfFloor      facing  \
# 694   Sushant Lok Phase 1, Gurgaon, Haryana  5 Floors        West
# 150   Sushant Lok Phase 1, Gurgaon, Haryana  2 Floors  South-West
# 961       Uppals Southend, Gurgaon, Haryana  3 Floors        West
# 195           Maruti Kunj, Gurgaon, Haryana  2 Floors         NaN
# 13   A Block, DLF Phase 1, Gurgaon, Haryana  3 Floors       North
#
#         agePossession                                    nearbyLocations  \
# 694   0 to 1 Year Old  ['Sector 42-43 metro station', 'Huda city cent...
# 150   1 to 5 Year Old  ['Huda city centre metro station', 'Sector 42-...
# 961   1 to 5 Year Old  ['Sri Radhe Krishna Temple', 'Icici bank ATM',...
# 195  5 to 10 Year Old                                                NaN
# 13   5 to 10 Year Old  ['Guru dronacharya metro station', 'Dlf phase ...
#
#                                            description  \
# 694  Best for investors , monthly rental income is ...
# 150  Available for sell 6bhk independent house vill...
# 961  Uppal southend sector 49.Gated society plot si...
# 195  Interested to sell independent house/villa.It ...
# 13   Genuine livable kothi at the rate of plot only...
#
#                                         furnishDetails  \
# 694  ['1 Water Purifier', '11 Fan', '1 Fridge', '1 ...
# 150  ['6 Wardrobe', '5 Fan', '1 Exhaust Fan', '5 Ge...
# 961  ['12 Wardrobe', '20 Fan', '1 Exhaust Fan', '12...
# 195                                                 []
# 13   ['5 Wardrobe', '9 Fan', '1 Exhaust Fan', '6 Ge...
#
#                                               features  \
# 694  ['Maintenance Staff', 'Water Storage', 'Park',...
# 150  ['Feng Shui / Vaastu Compliant', 'Private Gard...
# 961  ['Feng Shui / Vaastu Compliant', 'Maintenance ...
# 195                                                NaN
# 13   ['Feng Shui / Vaastu Compliant', 'Private Gard...
#
#                                                 rating
# 694  ['Environment5 out of 5', 'Lifestyle5 out of 5...
# 150  ['Environment5 out of 5', 'Lifestyle5 out of 5...
# 961  ['Environment5 out of 5', 'Safety5 out of 5', ...
# 195  ['Environment4 out of 5', 'Lifestyle4 out of 5...
# 13   ['Environment5 out of 5', 'Lifestyle5 out of 5...

# %%
# balcony
df['balcony'].value_counts()
# Out:
# 3+ Balconies    365
# 2 Balconies     220
# 3 Balconies     159
# No Balcony      115
# 1 Balcony       105
# Name: balcony, dtype: int64

# %%
df['balcony'].isnull().sum()
# Out:
# 0

# %%
df['balcony'] = df['balcony'].str.split(' ').str.get(0).str.replace('No', '0')

# %%
# additional Room
df['additionalRoom'].value_counts()
# Out:
# Servant Room                                     81
# Pooja Room,Study Room,Servant Room,Store Room    60
# Others                                           58
# Pooja Room                                       38
# Pooja Room,Study Room,Servant Room               33
#                                                  ..
# Servant Room,Others,Pooja Room                    1
# Study Room,Store Room,Servant Room,Pooja Room     1
# Store Room,Study Room,Servant Room                1
# Store Room,Servant Room,Pooja Room                1
# Study Room,Others,Servant Room                    1
# Name: additionalRoom, Length: 56, dtype: int64

# %%
df['additionalRoom'].value_counts().shape
# Out:
# (56,)

# %%
df['additionalRoom'].isnull().sum()
# Out:
# 386

# %%
df['additionalRoom'].fillna('not available', inplace=True)

# %%
df['additionalRoom'] = df['additionalRoom'].str.lower()

# %%
df.sample(5)
# Out:
#                                          property_name      society  price  \
# 29         5 Bedroom House for sale in Nirvana Country  independent  10.56
# 80       4 Bedroom House for sale in Sector 23 Gurgaon  independent   5.00
# 715     3 Bedroom House for sale in Sector 23A Gurgaon  independent   5.10
# 890  5 Bedroom House for sale in A Block Sushant Lo...  independent   9.85
# 217            3 Bedroom House for sale in Ashok Vihar  independent   1.50
#
#      price_per_sqft                   area  \
# 29          32593.0  (301 sq.m.) Plot Area
# 80          16244.0  (286 sq.m.) Plot Area
# 715         16569.0  (286 sq.m.) Plot Area
# 890         29638.0  (350 sq.m.) Plot Area
# 217         10288.0  (135 sq.m.) Plot Area
#
#                                           areaWithType  bedRoom  bathroom  \
# 29                         Plot area 360(301.01 sq.m.)        5         5
# 80                         Plot area 342(285.96 sq.m.)        4         4
# 715  Plot area 342(285.96 sq.m.)Built Up area: 125 ...        3         2
# 890                         Plot area 418(349.5 sq.m.)        5         5
# 217  Plot area 162(135.45 sq.m.)Built Up area: 210 ...        3         3
#
#     balcony                      additionalRoom  \
# 29        3                        servant room
# 80        2                       not available
# 715       0                              others
# 890       2  pooja room,study room,servant room
# 217       0                       not available
#
#                                                address noOfFloor facing  \
# 29                   Nirvana Country, Gurgaon, Haryana  3 Floors    NaN
# 80                 Sector 23 Gurgaon, Gurgaon, Haryana  2 Floors   East
# 715               Sector 23A Gurgaon, Gurgaon, Haryana  1 Floors   East
# 890      A Block Sushant Lok Phase 1, Gurgaon, Haryana  3 Floors   West
# 217  800 Lane 8 Ashok Vihar Part 1, Ashok Vihar, Gu...       NaN    NaN
#
#         agePossession                                    nearbyLocations  \
# 29   5 to 10 Year Old  ['Radhakrishna Shani Mandir', 'Standard charte...
# 80       10+ Year Old  ['HUDA Sector 23 Market', 'Palam triangle', 'P...
# 715      10+ Year Old  ['HUDA Sector 23 Market', 'Palam triangle', 'P...
# 890      10+ Year Old  ['Mg road metro station', 'Iffco chowk metro s...
# 217      10+ Year Old  ['Chintapurni Mandir', 'Sheetla Mata Mandir', ...
#
#                                            description  \
# 29   Urgent for sale\nOn main wide road\nConfirm de...
# 80   Wishing to settle down in an individual house ...
# 715  342 sq yards size of 2bhk with servant room av...
# 890  Sushant lok a maple community gated line near ...
# 217      Ground floor and partial first floor built up
#
#                                         furnishDetails  \
# 29                                                 NaN
# 80   ['4 Wardrobe', '6 Fan', '10 Light', '1 Modular...
# 715  ['1 Wardrobe', '1 Fan', '1 Exhaust Fan', '1 Ge...
# 890                                                NaN
# 217                                                 []
#
#                                               features  \
# 29   ['Maintenance Staff', 'Water Storage', 'Visito...
# 80                                   ['Water Storage']
# 715  ['Feng Shui / Vaastu Compliant', 'Water Storag...
# 890   ['Maintenance Staff', 'Park', 'Visitor Parking']
# 217                                                NaN
#
#                                                 rating
# 29   ['Environment5 out of 5', 'Lifestyle5 out of 5...
# 80   ['Environment4 out of 5', 'Lifestyle5 out of 5...
# 715  ['Environment5 out of 5', 'Lifestyle4 out of 5...
# 890  ['Environment4 out of 5', 'Safety3 out of 5', ...
# 217  ['Environment4 out of 5', 'Lifestyle4 out of 5...

# %%
# floor num
df.rename(columns={'noOfFloor': 'floorNum'}, inplace=True)

# %%
df.sample(5)
# Out:
#                                          property_name  \
# 197            4 Bedroom House for sale in Mohan Nagar
# 436           1 Bedroom House for sale in Laxman Vihar
# 185             2 Bedroom House for sale in Daulatabad
# 922     4 Bedroom House for sale in Sector 109 Gurgaon
# 248  2 Bedroom House for sale in Ashok Vihar Phase ...
#
#                                          society  price  price_per_sqft  \
# 197                                  independent   1.30          8701.0
# 436                               not applicable   0.40          9259.0
# 185  secter 16a daultabad faridabad house no 313   0.48         60000.0
# 922          international city by sobha phase 1   6.00          9634.0
# 248                                  independent   0.75         57692.0
#
#                          area                      areaWithType  bedRoom  \
# 197     (139 sq.m.) Plot Area        Plot area 166(138.8 sq.m.)        4
# 436      (40 sq.m.) Plot Area        Plot area 432(40.13 sq.m.)        1
# 185       (7 sq.m.) Plot Area          Plot area 80(7.43 sq.m.)        2
# 922     (579 sq.m.) Plot Area        Plot area 692(578.6 sq.m.)        4
# 248  (12 sq.m.) Built-up Area  Built Up area: 130 (12.08 sq.m.)        2
#
#      bathroom balcony additionalRoom  \
# 197         4       2  not available
# 436         1       1  not available
# 185         2       0  not available
# 922         5       3  not available
# 248         2       0  not available
#
#                                                address   floorNum      facing  \
# 197                      Mohan Nagar, Gurgaon, Haryana   1 Floors        East
# 436                     Laxman Vihar, Gurgaon, Haryana   1 Floors         NaN
# 185                  313, Daulatabad, Gurgaon, Haryana  02 Floors  South-East
# 922          N/a, Sector 109 Gurgaon, Gurgaon, Haryana   2 Floors  North-East
# 248  Ashok Vihar Phase 3 Extension, Ashok Vihar Pha...   1 Floors         NaN
#
#         agePossession                                    nearbyLocations  \
# 197      10+ Year Old  ['Astha Hospital', 'Kamal Hospital and Materni...
# 436  5 to 10 Year Old  ['Chintapurni Mandir', 'State bank ATM', 'Prat...
# 185   1 to 5 Year Old  ['R K Hospital Gurgaon', 'Bhardwaj Hospital', ...
# 922  5 to 10 Year Old  ['Dwarka sector 21 metro station', 'Pacific D2...
# 248         undefined                                                NaN
#
#                                            description  \
# 197  This 4 bhk house for sale in mohan nagar, a we...
# 436  Looking for buyer to purchase our house/villa ...
# 185  Check out this 2 bhk house for sale in daulata...
# 922  Property description: On the lookout for a spa...
# 248  This spacious residential house has total 1 fl...
#
#                                         furnishDetails  \
# 197                                                NaN
# 436                                                 []
# 185                                                NaN
# 922                                                 []
# 248  ['1 Wardrobe', '1 Fan', '1 Light', 'No AC', 'N...
#
#                                               features  \
# 197                                                NaN
# 436                                                NaN
# 185      ['Private Garden / Terrace', 'Water Storage']
# 922  ['Feng Shui / Vaastu Compliant', 'High Ceiling...
# 248                                                NaN
#
#                                                 rating
# 197                                                NaN
# 436  ['Environment4 out of 5', 'Lifestyle4 out of 5...
# 185                                                NaN
# 922  ['Environment5 out of 5', 'Safety4.5 out of 5'...
# 248  ['Environment3 out of 5', 'Lifestyle4 out of 5...

# %%
df['floorNum'].value_counts().shape
# Out:
# (20,)

# %%
df['floorNum'].isnull().sum()
# Out:
# 19

# %%
df['floorNum'] = df['floorNum'].str.split(' ').str.get(0).str.replace('Ground', '0').str.replace('Basement', '-1').str.replace('Lower', '0').str.extract(r'(\d+)')

# %%
df.sample(5)
# Out:
#                                        property_name               society  \
# 863    3 Bedroom House for sale in Sector 49 Gurgaon  eros rosewood villas
# 424   3 Bedroom House for sale in Sector 103 Gurgaon           independent
# 909         16 Bedroom House for sale in DLF Phase 2           independent
# 239   3 Bedroom House for sale in Sector 109 Gurgaon        ats tourmaline
# 249  6 Bedroom House for sale in Surat Nagar Phase 2           independent
#
#      price  price_per_sqft                       area  \
# 863   2.80         15555.0      (142 sq.m.) Plot Area
# 424   2.25          6367.0  (328 sq.m.) Built-up Area
# 909  16.00         59259.0      (293 sq.m.) Plot Area
# 239   1.87          8697.0  (200 sq.m.) Built-up Area
# 249   0.30         60000.0        (5 sq.m.) Plot Area
#
#                                           areaWithType  bedRoom  bathroom  \
# 863  Plot area 1530(142.14 sq.m.)Built Up area: 190...        3         3
# 424  Built Up area: 3534 (328.32 sq.m.)Carpet area:...        3         5
# 909  Plot area 350(292.64 sq.m.)Built Up area: 325 ...       16        16
# 239                 Built Up area: 2150 (199.74 sq.m.)        3         4
# 249                           Plot area 50(4.65 sq.m.)        6         3
#
#     balcony                                 additionalRoom  \
# 863       3                                     pooja room
# 424      3+                                  not available
# 909      3+  servant room,study room,pooja room,store room
# 239       0                                  not available
# 249       3                                  not available
#
#                                               address floorNum facing  \
# 863          A22, Sector 49 Gurgaon, Gurgaon, Haryana        2   East
# 424  Sector 103, Sector 103 Gurgaon, Gurgaon, Haryana       10  South
# 909        Dlf Phase 2, DLF Phase 2, Gurgaon, Haryana        4   West
# 239  Sector 109, Sector 109 Gurgaon, Gurgaon, Haryana       12    NaN
# 249        814, Surat Nagar Phase 2, Gurgaon, Haryana        3  South
#
#         agePossession                                    nearbyLocations  \
# 863  5 to 10 Year Old  ['Sri Radhe Krishna Temple', 'Standard charter...
# 424         undefined                                                NaN
# 909   0 to 1 Year Old  ['Vodafone belvedere towers metro station', 'D...
# 239         undefined  ['Dwarka Sector 21 Metro Station', 'NeoSquare ...
# 249  5 to 10 Year Old  ['Chintapurni Mandir', 'State bank ATM', 'Dr. ...
#
#                                            description  \
# 863  3 bhk duplex villa for sale in rosewood city w...
# 424  3bhk penthouse for resale in sector 103 sector...
# 909  Dlf phase 2 very prime location , this buildin...
# 239  A residential house is available for sale. It ...
# 249  Wishing to settle down in an individual house ...
#
#                                         furnishDetails  \
# 863  ['3 Wardrobe', '4 Fan', '4 Light', '1 Chimney'...
# 424                                                NaN
# 909  ['1 Water Purifier', '24 Fan', '1 Exhaust Fan'...
# 239                                                NaN
# 249                                                 []
#
#                                               features  \
# 863  ['Private Garden / Terrace', 'High Ceiling Hei...
# 424                                                NaN
# 909  ['Feng Shui / Vaastu Compliant', 'Private Gard...
# 239                                                NaN
# 249                                                NaN
#
#                                                 rating
# 863  ['Environment4 out of 5', 'Safety5 out of 5', ...
# 424  ['Environment4 out of 5', 'Lifestyle4 out of 5...
# 909  ['Environment5 out of 5', 'Safety5 out of 5', ...
# 239  ['Environment5 out of 5', 'Lifestyle4 out of 5...
# 249                                                NaN

# %%
# facing
df['facing'].isnull().sum()
# Out:
# 303

# %%
df['facing'].fillna('NA', inplace=True)

# %%
df['facing'].value_counts()
# Out:
# NA            303
# East          178
# North-East    158
# North         109
# West           75
# North-West     44
# South-East     39
# South          34
# South-West     24
# Name: facing, dtype: int64

# %%
df['area'] = round((df['price']*10000000/df['price_per_sqft']))

# %%
df.insert(loc=1, column='property_type', value='house')

# %%
df.head()
# Out:
#                                       property_name property_type  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon         house
# 1  5 Bedroom House for sale in Sector 21A Faridabad         house
# 2  10 Bedroom House for sale in Sushant Lok Phase 1         house
# 3    21 Bedroom House for sale in Sector 54 Gurgaon         house
# 4  12 Bedroom House for sale in Sushant Lok Phase 1         house
#
#             society  price  price_per_sqft    area  \
# 0  bptp visionnaire   5.25         20115.0  2610.0
# 1       independent   5.70        105751.0   539.0
# 2       independent   2.10         38251.0   549.0
# 3       independent   5.00         43066.0  1161.0
# 4       independent   3.00         53763.0   558.0
#
#                   areaWithType  bedRoom  bathroom balcony  \
# 0  Plot area 290(242.48 sq.m.)        5         4      3+
# 1   Plot area 539(50.07 sq.m.)        5         4       2
# 2       Plot area 61(51 sq.m.)       10        10      3+
# 3  Plot area 129(107.86 sq.m.)       21        21      3+
# 4    Plot area 62(51.84 sq.m.)       12        12      3+
#
#                        additionalRoom  \
# 0                        servant room
# 1  store room,pooja room,servant room
# 2                        servant room
# 3                        servant room
# 4                              others
#
#                                        address floorNum      facing  \
# 0    29b, Sector 70A Gurgaon, Gurgaon, Haryana        3  North-East
# 1       Sector 21A Faridabad, Gurgaon, Haryana        2          NA
# 2        Sushant Lok Phase 1, Gurgaon, Haryana        5        West
# 3          Sector 54 Gurgaon, Gurgaon, Haryana        5       North
# 4  1228, Sushant Lok Phase 1, Gurgaon, Haryana        5        West
#
#       agePossession                                    nearbyLocations  \
# 0   0 to 1 Year Old  ['Good Earth City Center 2', 'Kunskapsskolan I...
# 1  5 to 10 Year Old                                                NaN
# 2   0 to 1 Year Old  ['Sector 42-43 metro station', 'Huda city cent...
# 3   1 to 5 Year Old  ['Sector 53-54 metro station', 'Sector 54 chow...
# 4   Within 6 months  ['Sector 42-43 metro station', 'Huda city cent...
#
#                                          description  \
# 0  Do you wish to buy an independent house in sec...
# 1  Hi, we have an independent house/villa availab...
# 2  Monthly rental income is rs1,40,000/- Best opt...
# 3  129 sq yd plot size. 5 floors built up , fully...
# 4  Best for investment purpose. Fully furnished b...
#
#                                       furnishDetails  \
# 0  ['1 Wardrobe', '1 Fan', '1 Exhaust Fan', '1 Ge...
# 1  ['1 Water Purifier', '5 Fan', '1 Exhaust Fan',...
# 2  ['10 Bed', '3 Fan', '10 Geyser', '2 Light', 'N...
# 3  ['1 Water Purifier', '21 Fan', '1 Fridge', '1 ...
# 4  ['1 Water Purifier', '1 Fridge', '12 Fan', '1 ...
#
#                                             features  \
# 0  ['Feng Shui / Vaastu Compliant', 'Private Gard...
# 1  ['Private Garden / Terrace', 'Park', 'Visitor ...
# 2  ['Maintenance Staff', 'Water Storage', 'Visito...
# 3  ['Feng Shui / Vaastu Compliant', 'Private Gard...
# 4  ['Maintenance Staff', 'Water Storage', 'Visito...
#
#                                               rating
# 0  ['Environment5 out of 5', 'Lifestyle4 out of 5...
# 1                                                NaN
# 2  ['Environment5 out of 5', 'Lifestyle5 out of 5...
# 3  ['Environment4 out of 5', 'Lifestyle5 out of 5...
# 4  ['Environment5 out of 5', 'Lifestyle5 out of 5...

# %%
df.shape
# Out:
# (964, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 964 entries, 0 to 1036
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    964 non-null    object
#  1   property_type    964 non-null    object
#  2   society          964 non-null    object
#  3   price            945 non-null    float64
#  4   price_per_sqft   945 non-null    float64
#  5   area             945 non-null    float64
#  6   areaWithType     964 non-null    object
#  7   bedRoom          964 non-null    int32
#  8   bathroom         964 non-null    int32
#  9   balcony          964 non-null    object
#  10  additionalRoom   964 non-null    object
#  11  address          959 non-null    object
#  12  floorNum         945 non-null    object
#  13  facing           964 non-null    object
#  14  agePossession    964 non-null    object
#  15  nearbyLocations  848 non-null    object
#  16  description      964 non-null    object
#  17  furnishDetails   729 non-null    object
#  18  features         662 non-null    object
#  19  rating           843 non-null    object
# dtypes: float64(3), int32(2), object(15)
# memory usage: 150.6+ KB

# %%
df.to_csv('../../Data_Scraping/Data/Gurgaon/Independent_House/ind_house_cleaned.csv', index=False)
