# %%
import pandas as pd
import numpy as np

# %%
# Display all the columns and rows
pd.set_option('display.max_rows', 10)
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('../Data/gurgaon_properties.csv', index_col='Unnamed: 0')

# %%
df.shape
# Out:
# (3961, 20)

# %%
df.sample(5)
# Out:
#                           property_name property_type  \
# 3628  3 BHK Flat in Sector 89 A Gurgaon          flat
# 2325   3 BHK Flat in Sector 37D Gurgaon          flat
# 1396    3 BHK Flat in Sector 86 Gurgaon          flat
# 1972    4 BHK Flat in Sector 92 Gurgaon          flat
# 840                 3 BHK Flat in Sohna          flat
#
#                          society  price  price_per_sqft    area  \
# 3628                ats marigold   1.85          8604.0  2150.0
# 2325  ramprastha the edge towers   1.00          5649.0  1770.0
# 1396        dlf new town heights   1.30          6735.0  1930.0
# 1972               sare petioles   1.30          6373.0  2040.0
# 840        signature global park   0.90          6254.0  1439.0
#
#                                 areaWithType  bedRoom  bathroom balcony  \
# 3628  Super Built up area 2150(199.74 sq.m.)        3         3      3+
# 2325  Super Built up area 1770(164.44 sq.m.)        3         3      3+
# 1396   Super Built up area 1930(179.3 sq.m.)        3         3       3
# 1972      Built Up area: 2040 (189.52 sq.m.)        4         4       0
# 840         Carpet area: 1439 (133.69 sq.m.)        3         3       3
#
#                additionalRoom                                         address  \
# 3628             servant room           Sector 89 A Gurgaon, Gurgaon, Haryana
# 2325            not available            Sector 37D Gurgaon, Gurgaon, Haryana
# 1396  servant room,pooja room             Sector 86 Gurgaon, Gurgaon, Haryana
# 1972            not available  Sector 92, Sector 92 Gurgaon, Gurgaon, Haryana
# 840                pooja room                   0001, Sohna, Gurgaon, Haryana
#
#       floorNum      facing     agePossession  \
# 3628      12.0  South-West   0 to 1 Year Old
# 2325      13.0         NaN  5 to 10 Year Old
# 1396      12.0        West  5 to 10 Year Old
# 1972       7.0         NaN         undefined
# 840        3.0  North-West   1 to 5 Year Old
#
#                                         nearbyLocations  \
# 3628  ['Reliance Trends Newtown Square Mall', 'Dwark...
# 2325  ['MDS Public School', 'St Pauls School', 'Sunc...
# 1396  ['City Square', 'Vatika Town Square', 'Bharat ...
# 1972                                                NaN
# 840   ['Sector 55-56 metro', 'Global city centre', '...
#
#                                             description furnishDetails  \
# 3628  The possession of the house would be in next 4...            NaN
# 2325   It semi- Furnished wardrobes and modular kitchen             []
# 1396  3 bhk with servant room available for sale in ...            NaN
# 1972  Best in class property available at sector 92 ...            NaN
# 840   Signature global park in sohna, gurgaon is a r...            NaN
#
#                                                features  \
# 3628  ['Security / Fire Alarm', 'Lift(s)', 'Maintena...
# 2325  ['Power Back-up', 'Intercom Facility', 'Lift(s...
# 1396  ['Security / Fire Alarm', 'Feng Shui / Vaastu ...
# 1972                                                NaN
# 840   ['Security / Fire Alarm', 'Feng Shui / Vaastu ...
#
#                                                  rating
# 3628                                                NaN
# 2325  ['Green Area4 out of 5', 'Amenities4 out of 5'...
# 1396  ['Green Area5 out of 5', 'Construction4.5 out ...
# 1972  ['Environment5 out of 5', 'Lifestyle4 out of 5...
# 840   ['Green Area5 out of 5', 'Construction5 out of...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3961 entries, 0 to 3960
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    3961 non-null   object
#  1   property_type    3961 non-null   object
#  2   society          3960 non-null   object
#  3   price            3941 non-null   float64
#  4   price_per_sqft   3941 non-null   float64
#  5   area             3941 non-null   float64
#  6   areaWithType     3961 non-null   object
#  7   bedRoom          3961 non-null   int64
#  8   bathroom         3961 non-null   int64
#  9   balcony          3961 non-null   object
#  10  additionalRoom   3961 non-null   object
#  11  address          3950 non-null   object
#  12  floorNum         3940 non-null   float64
#  13  facing           2784 non-null   object
#  14  agePossession    3960 non-null   object
#  15  nearbyLocations  3754 non-null   object
#  16  description      3961 non-null   object
#  17  furnishDetails   2929 non-null   object
#  18  features         3252 non-null   object
#  19  rating           3511 non-null   object
# dtypes: float64(4), int64(2), object(14)
# memory usage: 649.9+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# Inserting new feature sector for area indentification
df.insert(loc=3, column='sector', value=df['property_name'].str.split('in').str.get(1).str.replace('Gurgaon', '').str.strip())

# %%
df.sample(5)
# Out:
#                                     property_name property_type  \
# 306                           2 BHK Flat in Sohna          flat
# 1464              2 BHK Flat in Sector 74 Gurgaon          flat
# 191   5 Bedroom House for sale in Mianwali Colony         house
# 2905              3 BHK Flat in Sector 66 Gurgaon          flat
# 165              2 BHK Flat in Sector 108 Gurgaon          flat
#
#                        society           sector  price  price_per_sqft  \
# 306       breez global heights            Sohna   0.46          6478.0
# 1464               m3m skywalk        Sector 74   1.50         12500.0
# 191                independent  Mianwali Colony   1.50         11111.0
# 2905  emaar mgf the palm drive        Sector 66   2.80         14358.0
# 165     experion the heartsong       Sector 108   0.90          7014.0
#
#         area                                       areaWithType  bedRoom  \
# 306    710.0                     Carpet area: 710 (65.96 sq.m.)        2
# 1464  1200.0  Super Built up area 1400(130.06 sq.m.)Built Up...        2
# 191   1350.0                        Plot area 150(125.42 sq.m.)        5
# 2905  1950.0  Super Built up area 1950(181.16 sq.m.)Built Up...        3
# 165   1283.0  Super Built up area 1283(119.19 sq.m.)Built Up...        2
#
#       bathroom balcony                      additionalRoom  \
# 306          2       2                       not available
# 1464         2       3                          store room
# 191          5       2                       not available
# 2905         3       2  servant room,study room,pooja room
# 165          3       3                        servant room
#
#                                         address  floorNum      facing  \
# 306                606, Sohna, Gurgaon, Haryana       6.0        East
# 1464  1710, Sector 74 Gurgaon, Gurgaon, Haryana      17.0  North-East
# 191           Mianwali Colony, Gurgaon, Haryana       3.0         NaN
# 2905        Sector 66 Gurgaon, Gurgaon, Haryana      12.0        East
# 165        Sector 108 Gurgaon, Gurgaon, Haryana       2.0       South
#
#         agePossession                                    nearbyLocations  \
# 306   1 to 5 Year Old  ['Raheja Mall', 'Golf Course Extension Road', ...
# 1464  1 to 5 Year Old  ['Omaxe Gurgaon Mall', 'Omaxe Celebration Mall...
# 191      10+ Year Old  ['Hanuman Mandir', 'Sheetla Mata Mandir', 'M G...
# 2905  0 to 1 Year Old  ['Sector 55-56 Rapid Metro Station', 'HUB 66',...
# 165   1 to 5 Year Old  ['Galleria 108 Mall', 'Dwarka Expressway', 'Ce...
#
#                                             description  \
# 306   Unit is fully functional and loaded with some ...
# 1464  This 2 bhk flat is located in m3m skywalk, whi...
# 191                 3 storey independent house for sale
# 2905  Emaar palm drive apartment available for sale ...
# 165   Why you should consider experion the heartsong...
#
#                                          furnishDetails  \
# 306   ['1 Water Purifier', '3 Fan', '1 Fridge', '1 E...
# 1464                                                NaN
# 191                                                  []
# 2905  ['6 Fan', '1 Fridge', '1 Exhaust Fan', '1 Dini...
# 165   ['1 Wardrobe', '1 Fan', '1 Light', '1 AC', 'No...
#
#                                                features  \
# 306   ['Feng Shui / Vaastu Compliant', 'Security / F...
# 1464  ['Water purifier', 'Centrally Air Conditioned'...
# 191   ['Centrally Air Conditioned', 'Internet/wi-fi ...
# 2905  ['Security / Fire Alarm', 'Power Back-up', 'In...
# 165   ['Power Back-up', 'Feng Shui / Vaastu Complian...
#
#                                                  rating
# 306   ['Green Area5 out of 5', 'Construction5 out of...
# 1464                                                NaN
# 191   ['Environment3.5 out of 5', 'Lifestyle4 out of...
# 2905  ['Green Area5 out of 5', 'Construction4.5 out ...
# 165   ['Green Area5 out of 5', 'Construction4 out of...

# %%
df['sector'] = df['sector'].str.lower()

# %%
df.head()
# Out:
#                                     property_name property_type  \
# 0                 4 BHK Flat in Sector 85 Gurgaon          flat
# 1                 2 BHK Flat in Sector 68 Gurgaon          flat
# 2                             2 BHK Flat in Sohna          flat
# 3  10 Bedroom House for sale in Sector 38 Gurgaon         house
# 4                4 BHK Flat in Sector 111 Gurgaon          flat
#
#                   society      sector  price  price_per_sqft    area  \
# 0             ss the leaf   sector 85   2.20          6934.0  3173.0
# 1           m3m sierra 68   sector 68   1.08          8674.0  1245.0
# 2           ashiana anmol       sohna   0.99          8215.0  1205.0
# 3             independent   sector 38   8.00        230547.0   347.0
# 4  puri diplomatic greens  sector 111   3.70         12542.0  2950.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0             Super Built up area 2812(261.24 sq.m.)        4         5
# 1  Super Built up area 1245(115.66 sq.m.)Built Up...        2         2
# 2  Super Built up area 1205(111.95 sq.m.)Carpet a...        2         2
# 3  Built Up area: 347 (32.24 sq.m.)Carpet area: 2...       10        10
# 4  Super Built up area 2950(274.06 sq.m.)Built Up...        4         5
#
#   balcony additionalRoom                                            address  \
# 0      3+  not available                Sector 85 Gurgaon, Gurgaon, Haryana
# 1       3  not available           T-8, Sector 68 Gurgaon, Gurgaon, Haryana
# 2       2  not available                            Sohna, Gurgaon, Haryana
# 3      3+  not available     Sector 38, Sector 38 Gurgaon, Gurgaon, Haryana
# 4      3+   servant room  Puri Diplomatic Greens, Sector 111 Gurgaon, Gu...
#
#    floorNum      facing    agePossession  \
# 0       4.0        East  1 to 5 Year Old
# 1       1.0        West  1 to 5 Year Old
# 2       6.0        East           Jul-25
# 3       1.0       North        undefined
# 4      12.0  South-East  1 to 5 Year Old
#
#                                      nearbyLocations  \
# 0  ['Sapphire 83 Mall', 'Dwarka Expressway', 'Cen...
# 1  ['Airia Mall', 'Sohna Road', 'Golf Course Exte...
# 2  ['Global Signum Plaza', 'Airia Mall', 'Sohna R...
# 3  ['Raja nahar singh metro station', 'Shiv Shakt...
# 4  ['Dwarka Sector 21 Metro Station', 'Gurgaon Dr...
#
#                                          description  \
# 0  Ss the leaf is offering a 4bhk apartment in se...
# 1  M3m sierra 68 in sector 68, gurgaon is a ready...
# 2  2bhk on sohna road, near educational hubs, new...
# 3  14 bhk villa fully furnished and rented out fo...
# 4  Situated in sector-111 gurgaon, puri diplomati...
#
#                                       furnishDetails  \
# 0  ['1 Light', 'No AC', 'No Bed', 'No Chimney', '...
# 1  ['2 Wardrobe', '7 Fan', '1 Exhaust Fan', '2 Ge...
# 2                                                NaN
# 3  ['1 Wardrobe', '1 Fan', '1 Light', 'No AC', 'N...
# 4  ['4 Wardrobe', '8 Fan', '1 Exhaust Fan', '4 Ge...
#
#                                             features  \
# 0  ['Intercom Facility', 'Lift(s)', 'Maintenance ...
# 1  ['Security / Fire Alarm', 'Power Back-up', 'Fe...
# 2  ['Feng Shui / Vaastu Compliant', 'Security / F...
# 3                                                NaN
# 4  ['Centrally Air Conditioned', 'Security / Fire...
#
#                                               rating
# 0  ['Green Area4.5 out of 5', 'Construction4.5 ou...
# 1  ['Environment4 out of 5', 'Lifestyle4 out of 5...
# 2  ['Green Area4 out of 5', 'Construction3 out of...
# 3  ['Environment4 out of 5', 'Lifestyle4 out of 5...
# 4  ['Green Area5 out of 5', 'Construction5 out of...

# %%
df['sector'].value_counts()
# Out:
# sohna                            163
# sector 102                       113
# sector 85                        110
# sector 92                        104
# sector 69                         94
#                                 ...
# sector 37b                         1
# old delhi road, opp sector-14      1
# alipur                             1
# ashok vihar phase 3                1
# ats marigold                       1
# Name: sector, Length: 301, dtype: int64

# %% [markdown]
# # Replacing all names with sectors

# %%
df['sector'] = df['sector'].str.replace('dharam colony','sector 12')
df['sector'] = df['sector'].str.replace('krishna colony','sector 7')
df['sector'] = df['sector'].str.replace('suncity','sector 54')
df['sector'] = df['sector'].str.replace('prem nagar','sector 13')
df['sector'] = df['sector'].str.replace('mg road','sector 28')
df['sector'] = df['sector'].str.replace('gandhi nagar','sector 28')
df['sector'] = df['sector'].str.replace('laxmi garden','sector 11')
df['sector'] = df['sector'].str.replace('shakti nagar','sector 11')

# %%
df['sector'] = df['sector'].str.replace('baldev nagar','sector 7')
df['sector'] = df['sector'].str.replace('shivpuri','sector 7')
df['sector'] = df['sector'].str.replace('garhi harsaru','sector 17')
df['sector'] = df['sector'].str.replace('imt manesar','manesar')
df['sector'] = df['sector'].str.replace('adarsh nagar','sector 12')
df['sector'] = df['sector'].str.replace('shivaji nagar','sector 11')
df['sector'] = df['sector'].str.replace('bhim nagar','sector 6')
df['sector'] = df['sector'].str.replace('madanpuri','sector 7')

# %%
df['sector'] = df['sector'].str.replace('saraswati vihar','sector 28')
df['sector'] = df['sector'].str.replace('arjun nagar','sector 8')
df['sector'] = df['sector'].str.replace('ravi nagar','sector 9')
df['sector'] = df['sector'].str.replace('vishnu garden','sector 105')
df['sector'] = df['sector'].str.replace('bhondsi','sector 11')
df['sector'] = df['sector'].str.replace('surya vihar','sector 21')
df['sector'] = df['sector'].str.replace('devilal colony','sector 9')
df['sector'] = df['sector'].str.replace('valley view estate','gwal pahari')

# %%
df['sector'] = df['sector'].str.replace('mehrauli  road','sector 14')
df['sector'] = df['sector'].str.replace('jyoti park','sector 7')
df['sector'] = df['sector'].str.replace('ansal plaza','sector 23')
df['sector'] = df['sector'].str.replace('dayanand colony','sector 6')
df['sector'] = df['sector'].str.replace('sushant lok phase 2','sector 55')
df['sector'] = df['sector'].str.replace('chakkarpur','sector 28')
df['sector'] = df['sector'].str.replace('greenwood city','sector 45')
df['sector'] = df['sector'].str.replace('subhash nagar','sector 12')

# %%
df['sector'] = df['sector'].str.replace('sohna road road','sohna road')
df['sector'] = df['sector'].str.replace('malibu town','sector 47')
df['sector'] = df['sector'].str.replace('surat nagar 1','sector 104')
df['sector'] = df['sector'].str.replace('new colony','sector 7')
df['sector'] = df['sector'].str.replace('mianwali colony','sector 12')
df['sector'] = df['sector'].str.replace('jacobpura','sector 12')
df['sector'] = df['sector'].str.replace('rajiv nagar','sector 13')
df['sector'] = df['sector'].str.replace('ashok vihar','sector 3')

# %%
df['sector'] = df['sector'].str.replace('dlf phase 1','sector 26')
df['sector'] = df['sector'].str.replace('nirvana country','sector 50')
df['sector'] = df['sector'].str.replace('palam vihar','sector 2')
df['sector'] = df['sector'].str.replace('dlf phase 2','sector 25')
df['sector'] = df['sector'].str.replace('sushant lok phase 1','sector 43')
df['sector'] = df['sector'].str.replace('laxman vihar','sector 4')
df['sector'] = df['sector'].str.replace('dlf phase 4','sector 28')
df['sector'] = df['sector'].str.replace('dlf phase 3','sector 24')

# %%
df['sector'] = df['sector'].str.replace('sushant lok phase 3','sector 57')
df['sector'] = df['sector'].str.replace('dlf phase 5','sector 43')
df['sector'] = df['sector'].str.replace('rajendra park','sector 105')
df['sector'] = df['sector'].str.replace('uppals southend','sector 49')
df['sector'] = df['sector'].str.replace('sohna','sohna road')
df['sector'] = df['sector'].str.replace('ashok vihar phase 3 extension','sector 5')
df['sector'] = df['sector'].str.replace('south city 1','sector 41')
df['sector'] = df['sector'].str.replace('ashok vihar phase 2','sector 5')

# %%
# Only keeping sectors with more than 3 instances
ind = df['sector'].value_counts()[df['sector'].value_counts() >= 3]
df = df[df['sector'].isin(ind.index)]

# %%
df.shape
# Out:
# (3803, 21)

# %%
df['sector'].value_counts()
# Out:
# sohna road     163
# sector 102     113
# sector 85      110
# sector 92      104
# sector 69       94
#               ...
# patel nagar      3
# maruti kunj      3
# sector 73        3
# sector 88b       3
# sector 15        3
# Name: sector, Length: 131, dtype: int64

# %%
df['sector'] = df['sector'].str.replace('sector 95a','sector 95')
df['sector'] = df['sector'].str.replace('sector 23a','sector 23')
df['sector'] = df['sector'].str.replace('sector 12a','sector 12')
df['sector'] = df['sector'].str.replace('sector 3a','sector 3')
df['sector'] = df['sector'].str.replace('sector 110 a','sector 110')
df['sector'] = df['sector'].str.replace('patel nagar','sector 15')
df['sector'] = df['sector'].str.replace('a block sector 43','sector 43')
df['sector'] = df['sector'].str.replace('maruti kunj','sector 12')
df['sector'] = df['sector'].str.replace('b block sector 43','sector 43')
df['sector'] = df['sector'].str.replace('sector-33 sohna road','sector 33')
df['sector'] = df['sector'].str.replace('sector 1 manesar','manesar')
df['sector'] = df['sector'].str.replace('sector 4 phase 2','sector 4')
df['sector'] = df['sector'].str.replace('sector 1a manesar','manesar')
df['sector'] = df['sector'].str.replace('c block sector 43','sector 43')
df['sector'] = df['sector'].str.replace('sector 89 a','sector 89')
df['sector'] = df['sector'].str.replace('sector 2 extension','sector 2')
df['sector'] = df['sector'].str.replace('sector 36 sohna road','sector 36')

# %%
df[df['sector'] == 'new']
# Out:
#                   property_name property_type                       society  \
# 1654  4 BHK Flat in New Gurgaon          flat                        dlf 76
# 2150  4 BHK Flat in New Gurgaon          flat                    sare homes
# 2907  2 BHK Flat in New Gurgaon          flat                   green court
# 3415  2 BHK Flat in New Gurgaon          flat  takshila heights sector 37 c
#
#      sector  price  price_per_sqft    area  \
# 1654    new   4.00         11428.0  3500.0
# 2150    new   0.85          4786.0  1776.0
# 2907    new   0.38          5507.0   690.0
# 3415    new   0.67          5583.0  1200.0
#
#                                 areaWithType  bedRoom  bathroom balcony  \
# 1654        Carpet area: 3500 (325.16 sq.m.)        4         4       2
# 2150     Super Built up area 1776(165 sq.m.)        4         4       3
# 2907           Carpet area: 690 (64.1 sq.m.)        2         2       1
# 3415  Super Built up area 1200(111.48 sq.m.)        2         2       2
#
#                additionalRoom                        address  floorNum facing  \
# 1654  study room,servant room  New Gurgaon, Gurgaon, Haryana       4.0    NaN
# 2150            not available  New Gurgaon, Gurgaon, Haryana       3.0    NaN
# 2907            not available  New Gurgaon, Gurgaon, Haryana       7.0    NaN
# 3415            not available  New Gurgaon, Gurgaon, Haryana       3.0    NaN
#
#            agePossession                                    nearbyLocations  \
# 1654              Jun-27  ['Shri Balaji Hospital and Trauma Center', 'S....
# 2150    5 to 10 Year Old  ['Columbia Asia Hospital', 'Apex Multi Special...
# 2907  Under Construction  ['Ing bank ATM', 'Dcb bank ATM', 'Indus ind ba...
# 3415     1 to 5 Year Old  ['Shri Balaji Hospital and Trauma Center', 'S....
#
#                                             description  \
# 1654  This lovely 4 bhk apartment/flat in new gurgao...
# 2150  Located in the popular residential address of ...
# 2907  We are the proud owners of this 2 bhk apartmen...
# 3415  Check out this 2 bhk apartment for sale in tak...
#
#                                          furnishDetails  \
# 1654  ['6 Wardrobe', '1 Fridge', '8 Fan', '1 Exhaust...
# 2150                                                 []
# 2907                                                 []
# 3415                                                 []
#
#                                                features rating
# 1654  ['Security / Fire Alarm', 'Feng Shui / Vaastu ...    NaN
# 2150                                                NaN    NaN
# 2907  ['Intercom Facility', 'Lift(s)', 'Maintenance ...    NaN
# 3415  ['Lift(s)', 'Swimming Pool', 'Visitor Parking'...    NaN

# %%
df.loc[955,'sector'] = 'sector 37'
df.loc[2800,'sector'] = 'sector 92'
df.loc[2838,'sector'] = 'sector 90'
df.loc[2857,'sector'] = 'sector 76'

df[df['sector'] == 'new sector 2']
df.loc[[311,1072,1486,3040,3875],'sector'] = 'sector 110'

# %%
df.shape
# Out:
# (3803, 21)

# %%
# features to drop -> property_name, address, description
df.drop(columns=['property_name', 'address', 'description', 'rating'],inplace=True)

# %%
df.sample(5)
# Out:
#      property_type                     society       sector  price  \
# 2087         house                 independent    sector 14   5.00
# 3610         house  central park flower valley    sector 33   1.15
# 2545          flat                 m3m capital   sector 113   1.83
# 1473          flat             pareena mi casa    sector 68   1.15
# 1333          flat      krrish provence estate  gwal pahari   5.25
#
#       price_per_sqft    area  \
# 2087         22222.0  2250.0
# 3610          9349.0  1230.0
# 2545         13969.0  1310.0
# 1473          9236.0  1245.0
# 1333          9051.0  5800.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 2087                        Plot area 250(209.03 sq.m.)        3         3
# 3610  Plot area 1737(161.37 sq.m.)Built Up area: 140...        2         2
# 2545                  Built Up area: 1310 (121.7 sq.m.)        2         2
# 1473             Super Built up area 1245(115.66 sq.m.)        2         2
# 1333             Super Built up area 5800(538.84 sq.m.)        4         5
#
#      balcony                      additionalRoom  floorNum      facing  \
# 2087       3                       not available       1.0       South
# 3610       3                          study room       2.0       North
# 2545       0                       not available       7.0         NaN
# 1473       3                       not available       8.0        East
# 1333      3+  pooja room,study room,servant room       2.0  North-East
#
#          agePossession                                    nearbyLocations  \
# 2087  5 to 10 Year Old  ['Sheetla Mata Mandir', 'Hsbc bank ATM', 'Hdfc...
# 3610   1 to 5 Year Old  ['Airia Mall', 'NH 248A', 'NE 4, Haryana', 'GD...
# 2545         undefined  ['Phase 2 Metro Station', 'Global Foyer Mall',...
# 1473   0 to 1 Year Old  ['Sector 55-56 Metro Station', 'Airia Mall', '...
# 1333   0 to 1 Year Old  ['Tniy Toons School', 'Pathways School Gurgoan...
#
#                                          furnishDetails  \
# 2087                                                NaN
# 3610  ['4 Fan', '1 Exhaust Fan', '2 Geyser', '10 Lig...
# 2545                                                NaN
# 1473                                                 []
# 1333                                                NaN
#
#                                                features
# 2087  ['Private Garden / Terrace', 'No open drainage...
# 3610  ['Feng Shui / Vaastu Compliant', 'High Ceiling...
# 2545                                                NaN
# 1473  ['Feng Shui / Vaastu Compliant', 'Security / F...
# 1333  ['Feng Shui / Vaastu Compliant', 'Security / F...

# %%
df.duplicated(subset=df.columns[1:]).sum()
# Out:
# 119

# %%
df.to_csv('../Data/gurgaon_properties_v1.csv')
